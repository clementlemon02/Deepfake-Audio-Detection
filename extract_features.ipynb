# %%
#%pip install librosa
import pandas as pd 
import os 
import librosa 
import numpy as np

# %%
meta = pd.read_csv("release_in_the_wild/meta.csv")
meta.head()
meta['label'].unique()
real_data = meta[meta['label']== "bona-fide"]
spoof_data = meta[meta['label']== "spoof"]

def load_bf_audio_files(sr = 22050):
    audio_files = []
    for file in real_data['file']: 
        y, _ = librosa.load(f'release_in_the_wild/{file}', sr = sr)
        audio_files.append(y)

    return audio_files

real_audio = load_bf_audio_files()
len(real_audio)
label = ["bona-fide"] * len(real_audio)
label[:10]

def load_spoof_audio_files(sr = 22050):
    audio_files = []
    for file in spoof_data['file']: 
        y, _ = librosa.load(f'release_in_the_wild/{file}', sr = sr)
        audio_files.append(y)

    return audio_files
spoof_audio = load_spoof_audio_files()
spoof_label = ['spoof'] * len(spoof_audio)
len(spoof_label)
label.extend(spoof_label)
len(label)
audio_data = real_audio.copy()
audio_data.extend(spoof_audio)
len(audio_data)
# Out:
# 31779

# %%
array = pd.Series(label)
value_counts = array.value_counts()
print(value_counts)
# Out:
# bona-fide    19963
# spoof        11816
# dtype: int64

# %% [markdown]
# ## Audio Feature Extraction

# %% [markdown]
# ### Audio Features Description
#
# #### Time-Domain Features
# These features focus on analyzing the audio waveform directly over time.
# 1. **Zero Crossing Rate:**  Counts how often the audio signal crosses the zero amplitude line. It’s a measure of **noisiness** or **percussiveness**, with higher rates indicating noisier sounds.
#
# 2. **RMS (Root Mean Square Energy):**  Measures the **energy** (or loudness) of the audio signal over time. It provides a sense of how strong or weak the audio is at different moments.
#
#
# #### Frequency-Domain Features
# These techniques convert audio from the time domain to the frequency domain, where more information about pitch and timbre is revealed.
#
# 1. **MFCCs (Mel-Frequency Cepstral Coefficients):**  A set of features that represent the **short-term power spectrum** of sound based on the Mel scale, which approximates human hearing. MFCCs are widely used in speech and audio processing, especially for tasks like **speech recognition** and **audio classification**. The first few coefficients capture the general shape of the spectrum (timbre), while the higher ones capture more detailed characteristics.
#
# 2. **Spectral Centroid:**  Indicates the "center of mass" of the spectrum, representing the **brightness** of the sound. Higher values correspond to brighter sounds with more high frequencies.
#
# 3. **Spectral Bandwidth:**  Measures the range of frequencies around the spectral centroid. It represents the **spread** or **width** of the spectrum, capturing whether the sound is concentrated in a narrow or wide range of frequencies.
#
# 4. **Spectral Rolloff:**  The frequency below which a certain percentage (e.g., 85%) of the total spectral energy lies. It’s often used to differentiate between **tonal** and **noisy** signals.
#
#
# #### Time-Frequency Domain Features
# These techniques combine both time and frequency information for better detection.
#
# 1. **Chroma STFT (Short-Time Fourier Transform):**  Represents the **pitch class profile**, showing how energy is distributed across different pitch classes (like musical notes) over time. Useful for identifying harmonic and melodic content in the audio.

# %%
# Sampling rate (standardize to 16 kHz)
target_sr = 16000

# Initialize an empty list to hold feature dictionaries
features_list = []

# Loop through each audio file path
for i in range(len(audio_data)):
    # Load audio file and resample to target_sr
    y = audio_data[i]
    sr = target_sr
    
    # Extract features
    chroma_stft = np.mean(librosa.feature.chroma_stft(y=y, sr=sr))  # Chroma STFT
    rms = np.mean(librosa.feature.rms(y=y))  # Root Mean Square Energy
    spectral_centroid = np.mean(librosa.feature.spectral_centroid(y=y, sr=sr))  # Spectral Centroid
    spectral_bandwidth = np.mean(librosa.feature.spectral_bandwidth(y=y, sr=sr))  # Spectral Bandwidth
    rolloff = np.mean(librosa.feature.spectral_rolloff(y=y, sr=sr))  # Spectral Rolloff
    zero_crossing_rate = np.mean(librosa.feature.zero_crossing_rate(y=y))  # Zero Crossing Rate
    
    # MFCCs (first 20 coefficients)
    mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=20)
    mfccs_mean = np.mean(mfccs, axis=1)  # Take mean of each coefficient over time
    
    # Prepare feature dictionary for the current audio file
    features_dict = {
        'chroma_stft': chroma_stft,
        'rms': rms,
        'spectral_centroid': spectral_centroid,
        'spectral_bandwidth': spectral_bandwidth,
        'rolloff': rolloff,
        'zero_crossing_rate': zero_crossing_rate
    }
    
    # Add MFCCs (mfcc1, mfcc2, ..., mfcc20)
    for j in range(1, 21):
        features_dict[f'mfcc{j}'] = mfccs_mean[j-1]
    
    # Optionally, you can also add a label if you're working on a supervised task
    features_dict['label'] = label[i] # Example label
    print(i,label[i])
    
    # Append feature dictionary to the list
    features_list.append(features_dict)

# Convert the list of feature dictionaries to a pandas DataFrame
features_df = pd.DataFrame(features_list)

# Now you have a DataFrame with all extracted features
print(features_df.head())
# Out:
# 0 bona-fide
# 1 bona-fide
# 2 bona-fide
# 3 bona-fide
# 4 bona-fide
# 5 bona-fide
# 6 bona-fide
# 7 bona-fide
# 8 bona-fide
# 9 bona-fide
# 10 bona-fide
# 11 bona-fide
# 12 bona-fide
# 13 bona-fide
# 14 bona-fide
# 15 bona-fide
# 16 bona-fide
# 17 bona-fide
# 18 bona-fide
# 19 bona-fide
# 20 bona-fide
# 21 bona-fide
# 22 bona-fide
# 23 bona-fide
# 24 bona-fide
# 25 bona-fide
# 26 bona-fide
# 27 bona-fide
# 28 bona-fide
# 29 bona-fide
# 30 bona-fide
# 31 bona-fide
# 32 bona-fide
# 33 bona-fide
# 34 bona-fide
# 35 bona-fide
# 36 bona-fide
# 37 bona-fide
# 38 bona-fide
# 39 bona-fide
# 40 bona-fide
# 41 bona-fide
# 42 bona-fide
# 43 bona-fide
# 44 bona-fide
# 45 bona-fide
# 46 bona-fide
# 47 bona-fide
# 48 bona-fide
# 49 bona-fide
# 50 bona-fide
# 51 bona-fide
# 52 bona-fide
# 53 bona-fide
# 54 bona-fide
# 55 bona-fide
# 56 bona-fide
# 57 bona-fide
# 58 bona-fide
# 59 bona-fide
# 60 bona-fide
# 61 bona-fide
# 62 bona-fide
# 63 bona-fide
# 64 bona-fide
# 65 bona-fide
# 66 bona-fide
# 67 bona-fide
# 68 bona-fide
# 69 bona-fide
# 70 bona-fide
# 71 bona-fide
# 72 bona-fide
# 73 bona-fide
# 74 bona-fide
# 75 bona-fide
# 76 bona-fide
# 77 bona-fide
# 78 bona-fide
# 79 bona-fide
# 80 bona-fide
# 81 bona-fide
# 82 bona-fide
# 83 bona-fide
# 84 bona-fide
# 3223 bona-fide
# 3224 bona-fide
# 3225 bona-fide
# 3226 bona-fide
# 3227 bona-fide
# 3228 bona-fide
# 3229 bona-fide
# 3230 bona-fide
# 3231 bona-fide
# 3232 bona-fide
# 3233 bona-fide
# 3234 bona-fide
# 3235 bona-fide
# 3236 bona-fide
# 3237 bona-fide
# 3238 bona-fide
# 3239 bona-fide
# 3240 bona-fide
# 3241 bona-fide
# 3242 bona-fide
# 3243 bona-fide
# 3244 bona-fide
# 3245 bona-fide
# 3246 bona-fide
# 3247 bona-fide
# 3248 bona-fide
# 3249 bona-fide
# 3250 bona-fide
# 3251 bona-fide
# 3252 bona-fide
# 3253 bona-fide
# 3254 bona-fide
# 3255 bona-fide
# 3256 bona-fide
# 3257 bona-fide
# 3258 bona-fide
# 3259 bona-fide
# 3260 bona-fide
# 3261 bona-fide
# 3262 bona-fide
# 3263 bona-fide
# 3264 bona-fide
# 3265 bona-fide
# 3266 bona-fide
# 3267 bona-fide
# 3268 bona-fide
# 3269 bona-fide
# 3270 bona-fide
# 3271 bona-fide
# 3272 bona-fide
# 3273 bona-fide
# ...
# 30583 spoof
# 30584 spoof
# 30585 spoof
# 30586 spoof
# 30587 spoof
# 30588 spoof
# 30589 spoof
# 30590 spoof
# 30591 spoof
# 30592 spoof
# 30593 spoof
# 30594 spoof
# 30595 spoof
# 30596 spoof
# 30597 spoof
# 30598 spoof
# 30599 spoof
# 30600 spoof
# 30601 spoof
# 30602 spoof
# 30603 spoof
# 30604 spoof
# 30605 spoof
# 30606 spoof
# 30607 spoof
# 30608 spoof
# 30609 spoof
# 30610 spoof
# 30611 spoof
# 30612 spoof
# 30613 spoof
# 30614 spoof
# 30615 spoof
# 30616 spoof
# 30617 spoof
# 30618 spoof
# 30619 spoof
# 30620 spoof
# 30621 spoof
# 30622 spoof
# 30623 spoof
# 30624 spoof
# 30625 spoof
# 30626 spoof
# 30627 spoof
# 30628 spoof
# 30629 spoof
# 30630 spoof
# 30631 spoof
# 30632 spoof
# 30633 spoof
# 30634 spoof
# 30635 spoof
# 30636 spoof
# 30637 spoof
# 30638 spoof
# 30639 spoof
# 30640 spoof
# 30641 spoof
# 30642 spoof
# 30643 spoof
# 30644 spoof
# 30645 spoof
# 30646 spoof
# 30647 spoof
# 30648 spoof
# 30649 spoof
# 30650 spoof
# 30651 spoof
# 30652 spoof
# 30653 spoof
# 30654 spoof
# 30655 spoof
# 30656 spoof
# 30657 spoof
# 30658 spoof
# 30659 spoof
# 30660 spoof
# 30661 spoof
# 30662 spoof
# 30663 spoof
# 30664 spoof
# 30665 spoof
# 30666 spoof
# 30667 spoof
# 30668 spoof
# 30669 spoof
# 30670 spoof
# 30671 spoof
# 30672 spoof
# 30673 spoof
# 30674 spoof
# 30675 spoof
# 30676 spoof
# 30677 spoof
# 30678 spoof
# 30679 spoof
# 30680 spoof
# 30681 spoof
# 30682 spoof
# 30683 spoof
# 30684 spoof
# 30685 spoof
# 30686 spoof
# 30687 spoof
# 30688 spoof
# 30689 spoof
# 30690 spoof
# 30691 spoof
# 30692 spoof
# 30693 spoof
# 30694 spoof
# 30695 spoof
# 30696 spoof
# 30697 spoof
# 30698 spoof
# 30699 spoof
# 30700 spoof
# 30701 spoof
# 30702 spoof
# 30703 spoof
# 30704 spoof
# 30705 spoof
# 30706 spoof
# 30707 spoof
# 30708 spoof
# 30709 spoof
# 30710 spoof
# 30711 spoof
# 30712 spoof
# 30713 spoof
# 30714 spoof
# 30715 spoof
# 30716 spoof
# 30717 spoof
# 30718 spoof
# 30719 spoof
# 30720 spoof
# 30721 spoof
# 30722 spoof
# 30723 spoof
# 30724 spoof
# 30725 spoof
# 30726 spoof
# 30727 spoof
# 30728 spoof
# 30729 spoof
# 30730 spoof
# 30731 spoof
# 30732 spoof
# 30733 spoof
# 30734 spoof
# 30735 spoof
# 30736 spoof
# 30737 spoof
# 30738 spoof
# 30739 spoof
# 30740 spoof
# 30741 spoof
# 30742 spoof
# 30743 spoof
# 30744 spoof
# 30745 spoof
# 30746 spoof
# 30747 spoof
# 30748 spoof
# 30749 spoof
# 30750 spoof
# 30751 spoof
# 30752 spoof
# 30753 spoof
# 30754 spoof
# 30755 spoof
# 30756 spoof
# 30757 spoof
# 30758 spoof
# 30759 spoof
# 30760 spoof
# 30761 spoof
# 30762 spoof
# 30763 spoof
# 30764 spoof
# 30765 spoof
# 30766 spoof
# 30767 spoof
# 30768 spoof
# 30769 spoof
# 30770 spoof
# 30771 spoof
# 30772 spoof
# 30773 spoof
# 30774 spoof
# 30775 spoof
# 30776 spoof
# 30777 spoof
# 30778 spoof
# 30779 spoof
# 30780 spoof
# 30781 spoof
# 30782 spoof
# 30783 spoof
# 30784 spoof
# 30785 spoof
# 30786 spoof
# 30787 spoof
# 30788 spoof
# 30789 spoof
# 30790 spoof
# 30791 spoof
# 30792 spoof
# 30793 spoof
# 30794 spoof
# 30795 spoof
# 30796 spoof
# 30797 spoof
# 30798 spoof
# 30799 spoof
# 30800 spoof
# 30801 spoof
# 30802 spoof
# 30803 spoof
# 30804 spoof
# 30805 spoof
# 30806 spoof
# 30807 spoof
# 30808 spoof
# 30809 spoof
# 30810 spoof
# 30811 spoof
# 30812 spoof
# 30813 spoof
# 30814 spoof
# 30815 spoof
# 30816 spoof
# 30817 spoof
# 30818 spoof
# 30819 spoof
# 30820 spoof
# 30821 spoof
# 30822 spoof
# 30823 spoof
# 30824 spoof
# 30825 spoof
# 30826 spoof
# 30827 spoof
# 30828 spoof
# 30829 spoof
# 30830 spoof
# 30831 spoof
# 30832 spoof
# 30833 spoof
# 30834 spoof
# 30835 spoof
# 30836 spoof
# 30837 spoof
# 30838 spoof
# 30839 spoof
# 30840 spoof
# 30841 spoof
# 30842 spoof
# 30843 spoof
# 30844 spoof
# 30845 spoof
# 30846 spoof
# 30847 spoof
# 30848 spoof
# 30849 spoof
# 30850 spoof
# 30851 spoof
# 30852 spoof
# 30853 spoof
# 30854 spoof
# 30855 spoof
# 30856 spoof
# 30857 spoof
# 30858 spoof
# 30859 spoof
# 30860 spoof
# 30861 spoof
# 30862 spoof
# 30863 spoof
# 30864 spoof
# 30865 spoof
# 30866 spoof
# 30867 spoof
# 30868 spoof
# 30869 spoof
# 30870 spoof
# 30871 spoof
# 30872 spoof
# 30873 spoof
# 30874 spoof
# 30875 spoof
# 30876 spoof
# 30877 spoof
# 30878 spoof
# 30879 spoof
# 30880 spoof
# 30881 spoof
# 30882 spoof
# 30883 spoof
# 30884 spoof
# 30885 spoof
# 30886 spoof
# 30887 spoof
# 30888 spoof
# 30889 spoof
# 30890 spoof
# 30891 spoof
# 30892 spoof
# 30893 spoof
# 30894 spoof
# 30895 spoof
# 30896 spoof
# 30897 spoof
# 30898 spoof
# 30899 spoof
# 30900 spoof
# 30901 spoof
# 30902 spoof
# 30903 spoof
# 30904 spoof
# 30905 spoof
# 30906 spoof
# 30907 spoof
# 30908 spoof
# 30909 spoof
# 30910 spoof
# 30911 spoof
# 30912 spoof
# 30913 spoof
# 30914 spoof
# 30915 spoof
# 30916 spoof
# 30917 spoof
# 30918 spoof
# 30919 spoof
# 30920 spoof
# 30921 spoof
# 30922 spoof
# 30923 spoof
# 30924 spoof
# 30925 spoof
# 30926 spoof
# 30927 spoof
# 30928 spoof
# 30929 spoof
# 30930 spoof
# 30931 spoof
# 30932 spoof
# 30933 spoof
# 30934 spoof
# 30935 spoof
# 30936 spoof
# 30937 spoof
# 30938 spoof
# 30939 spoof
# 30940 spoof
# 30941 spoof
# 30942 spoof
# 30943 spoof
# 30944 spoof
# 30945 spoof
# 30946 spoof
# 30947 spoof
# 30948 spoof
# 30949 spoof
# 30950 spoof
# 30951 spoof
# 30952 spoof
# 30953 spoof
# 30954 spoof
# 30955 spoof
# 30956 spoof
# 30957 spoof
# 30958 spoof
# 30959 spoof
# 30960 spoof
# 30961 spoof
# 30962 spoof
# 30963 spoof
# 30964 spoof
# 30965 spoof
# 30966 spoof
# 30967 spoof
# 30968 spoof
# 30969 spoof
# 30970 spoof
# 30971 spoof
# 30972 spoof
# 30973 spoof
# 30974 spoof
# 30975 spoof
# 30976 spoof
# 30977 spoof
# 30978 spoof
# 30979 spoof
# 30980 spoof
# 30981 spoof
# 30982 spoof
# 30983 spoof
# 30984 spoof
# 30985 spoof
# 30986 spoof
# 30987 spoof
# 30988 spoof
# 30989 spoof
# 30990 spoof
# 30991 spoof
# 30992 spoof
# 30993 spoof
# 30994 spoof
# 30995 spoof
# 30996 spoof
# 30997 spoof
# 30998 spoof
# 30999 spoof
# 31000 spoof
# 31001 spoof
# 31002 spoof
# 31003 spoof
# 31004 spoof
# 31005 spoof
# 31006 spoof
# 31007 spoof
# 31008 spoof
# 31009 spoof
# 31010 spoof
# 31011 spoof
# 31012 spoof
# 31013 spoof
# 31014 spoof
# 31015 spoof
# 31016 spoof
# 31017 spoof
# 31018 spoof
# 31019 spoof
# 31020 spoof
# 31021 spoof
# 31022 spoof
# 31023 spoof
# 31024 spoof
# 31025 spoof
# 31026 spoof
# 31027 spoof
# 31028 spoof
# 31029 spoof
# 31030 spoof
# 31031 spoof
# 31032 spoof
# 31033 spoof
# 31034 spoof
# 31035 spoof
# 31036 spoof
# 31037 spoof
# 31038 spoof
# 31039 spoof
# 31040 spoof
# 31041 spoof
# 31042 spoof
# 31043 spoof
# 31044 spoof
# 31045 spoof
# 31046 spoof
# 31047 spoof
# 31048 spoof
# 31049 spoof
# 31050 spoof
# 31051 spoof
# 31052 spoof
# 31053 spoof
# 31054 spoof
# 31055 spoof
# 31056 spoof
# 31057 spoof
# 31058 spoof
# 31059 spoof
# 31060 spoof
# 31061 spoof
# 31062 spoof
# 31063 spoof
# 31064 spoof
# 31065 spoof
# 31066 spoof
# 31067 spoof
# 31068 spoof
# 31069 spoof
# 31070 spoof
# 31071 spoof
# 31072 spoof
# 31073 spoof
# 31074 spoof
# 31075 spoof
# 31076 spoof
# 31077 spoof
# 31078 spoof
# 31079 spoof
# 31080 spoof
# 31081 spoof
# 31082 spoof
# 31083 spoof
# 31084 spoof
# 31085 spoof
# 31086 spoof
# 31087 spoof
# 31088 spoof
# 31089 spoof
# 31090 spoof
# 31091 spoof
# 31092 spoof
# 31093 spoof
# 31094 spoof
# 31095 spoof
# 31096 spoof
# 31097 spoof
# 31098 spoof
# 31099 spoof
# 31100 spoof
# 31101 spoof
# 31102 spoof
# 31103 spoof
# 31104 spoof
# 31105 spoof
# 31106 spoof
# 31107 spoof
# 31108 spoof
# 31109 spoof
# 31110 spoof
# 31111 spoof
# 31112 spoof
# 31113 spoof
# 31114 spoof
# 31115 spoof
# 31116 spoof
# 31117 spoof
# 31118 spoof
# 31119 spoof
# 31120 spoof
# 31121 spoof
# 31122 spoof
# 31123 spoof
# 31124 spoof
# 31125 spoof
# 31126 spoof
# 31127 spoof
# 31128 spoof
# 31129 spoof
# 31130 spoof
# 31131 spoof
# 31132 spoof
# 31133 spoof
# 31134 spoof
# 31135 spoof
# 31136 spoof
# 31137 spoof
# 31138 spoof
# 31139 spoof
# 31140 spoof
# 31141 spoof
# 31142 spoof
# 31143 spoof
# 31144 spoof
# 31145 spoof
# 31146 spoof
# 31147 spoof
# 31148 spoof
# 31149 spoof
# 31150 spoof
# 31151 spoof
# 31152 spoof
# 31153 spoof
# 31154 spoof
# 31155 spoof
# 31156 spoof
# 31157 spoof
# 31158 spoof
# 31159 spoof
# 31160 spoof
# 31161 spoof
# 31162 spoof
# 31163 spoof
# 31164 spoof
# 31165 spoof
# 31166 spoof
# 31167 spoof
# 31168 spoof
# 31169 spoof
# 31170 spoof
# 31171 spoof
# 31172 spoof
# 31173 spoof
# 31174 spoof
# 31175 spoof
# 31176 spoof
# 31177 spoof
# 31178 spoof
# 31179 spoof
# 31180 spoof
# 31181 spoof
# 31182 spoof
# 31183 spoof
# 31184 spoof
# 31185 spoof
# 31186 spoof
# 31187 spoof
# 31188 spoof
# 31189 spoof
# 31190 spoof
# 31191 spoof
# 31192 spoof
# 31193 spoof
# 31194 spoof
# 31195 spoof
# 31196 spoof
# 31197 spoof
# 31198 spoof
# 31199 spoof
# 31200 spoof
# 31201 spoof
# 31202 spoof
# 31203 spoof
# 31204 spoof
# 31205 spoof
# 31206 spoof
# 31207 spoof
# 31208 spoof
# 31209 spoof
# 31210 spoof
# 31211 spoof
# 31212 spoof
# 31213 spoof
# 31214 spoof
# 31215 spoof
# 31216 spoof
# 31217 spoof
# 31218 spoof
# 31219 spoof
# 31220 spoof
# 31221 spoof
# 31222 spoof
# 31223 spoof
# 31224 spoof
# 31225 spoof
# 31226 spoof
# 31227 spoof
# 31228 spoof
# 31229 spoof
# 31230 spoof
# 31231 spoof
# 31232 spoof
# 31233 spoof
# 31234 spoof
# 31235 spoof
# 31236 spoof
# 31237 spoof
# 31238 spoof
# 31239 spoof
# 31240 spoof
# 31241 spoof
# 31242 spoof
# 31243 spoof
# 31244 spoof
# 31245 spoof
# 31246 spoof
# 31247 spoof
# 31248 spoof
# 31249 spoof
# 31250 spoof
# 31251 spoof
# 31252 spoof
# 31253 spoof
# 31254 spoof
# 31255 spoof
# 31256 spoof
# 31257 spoof
# 31258 spoof
# 31259 spoof
# 31260 spoof
# 31261 spoof
# 31262 spoof
# 31263 spoof
# 31264 spoof
# 31265 spoof
# 31266 spoof
# 31267 spoof
# 31268 spoof
# 31269 spoof
# 31270 spoof
# 31271 spoof
# 31272 spoof
# 31273 spoof
# 31274 spoof
# 31275 spoof
# 31276 spoof
# 31277 spoof
# 31278 spoof
# 31279 spoof
# 31280 spoof
# 31281 spoof
# 31282 spoof
# 31283 spoof
# 31284 spoof
# 31285 spoof
# 31286 spoof
# 31287 spoof
# 31288 spoof
# 31289 spoof
# 31290 spoof
# 31291 spoof
# 31292 spoof
# 31293 spoof
# 31294 spoof
# 31295 spoof
# 31296 spoof
# 31297 spoof
# 31298 spoof
# 31299 spoof
# 31300 spoof
# 31301 spoof
# 31302 spoof
# 31303 spoof
# 31304 spoof
# 31305 spoof
# 31306 spoof
# 31307 spoof
# 31308 spoof
# 31309 spoof
# 31310 spoof
# 31311 spoof
# 31312 spoof
# 31313 spoof
# 31314 spoof
# 31315 spoof
# 31316 spoof
# 31317 spoof
# 31318 spoof
# 31319 spoof
# 31320 spoof
# 31321 spoof
# 31322 spoof
# 31323 spoof
# 31324 spoof
# 31325 spoof
# 31326 spoof
# 31327 spoof
# 31328 spoof
# 31329 spoof
# 31330 spoof
# 31331 spoof
# 31332 spoof
# 31333 spoof
# 31334 spoof
# 31335 spoof
# 31336 spoof
# 31337 spoof
# 31338 spoof
# 31339 spoof
# 31340 spoof
# 31341 spoof
# 31342 spoof
# 31343 spoof
# 31344 spoof
# 31345 spoof
# 31346 spoof
# 31347 spoof
# 31348 spoof
# 31349 spoof
# 31350 spoof
# 31351 spoof
# 31352 spoof
# 31353 spoof
# 31354 spoof
# 31355 spoof
# 31356 spoof
# 31357 spoof
# 31358 spoof
# 31359 spoof
# 31360 spoof
# 31361 spoof
# 31362 spoof
# 31363 spoof
# 31364 spoof
# 31365 spoof
# 31366 spoof
# 31367 spoof
# 31368 spoof
# 31369 spoof
# 31370 spoof
# 31371 spoof
# 31372 spoof
# 31373 spoof
# 31374 spoof
# 31375 spoof
# 31376 spoof
# 31377 spoof
# 31378 spoof
# 31379 spoof
# 31380 spoof
# 31381 spoof
# 31382 spoof
# 31383 spoof
# 31384 spoof
# 31385 spoof
# 31386 spoof
# 31387 spoof
# 31388 spoof
# 31389 spoof
# 31390 spoof
# 31391 spoof
# 31392 spoof
# 31393 spoof
# 31394 spoof
# 31395 spoof
# 31396 spoof
# 31397 spoof
# 31398 spoof
# 31399 spoof
# 31400 spoof
# 31401 spoof
# 31402 spoof
# 31403 spoof
# 31404 spoof
# 31405 spoof
# 31406 spoof
# 31407 spoof
# 31408 spoof
# 31409 spoof
# 31410 spoof
# 31411 spoof
# 31412 spoof
# 31413 spoof
# 31414 spoof
# 31415 spoof
# 31416 spoof
# 31417 spoof
# 31418 spoof
# 31419 spoof
# 31420 spoof
# 31421 spoof
# 31422 spoof
# 31423 spoof
# 31424 spoof
# 31425 spoof
# 31426 spoof
# 31427 spoof
# 31428 spoof
# 31429 spoof
# 31430 spoof
# 31431 spoof
# 31432 spoof
# 31433 spoof
# 31434 spoof
# 31435 spoof
# 31436 spoof
# 31437 spoof
# 31438 spoof
# 31439 spoof
# 31440 spoof
# 31441 spoof
# 31442 spoof
# 31443 spoof
# 31444 spoof
# 31445 spoof
# 31446 spoof
# 31447 spoof
# 31448 spoof
# 31449 spoof
# 31450 spoof
# 31451 spoof
# 31452 spoof
# 31453 spoof
# 31454 spoof
# 31455 spoof
# 31456 spoof
# 31457 spoof
# 31458 spoof
# 31459 spoof
# 31460 spoof
# 31461 spoof
# 31462 spoof
# 31463 spoof
# 31464 spoof
# 31465 spoof
# 31466 spoof
# 31467 spoof
# 31468 spoof
# 31469 spoof
# 31470 spoof
# 31471 spoof
# 31472 spoof
# 31473 spoof
# 31474 spoof
# 31475 spoof
# 31476 spoof
# 31477 spoof
# 31478 spoof
# 31479 spoof
# 31480 spoof
# 31481 spoof
# 31482 spoof
# 31483 spoof
# 31484 spoof
# 31485 spoof
# 31486 spoof
# 31487 spoof
# 31488 spoof
# 31489 spoof
# 31490 spoof
# 31491 spoof
# 31492 spoof
# 31493 spoof
# 31494 spoof
# 31495 spoof
# 31496 spoof
# 31497 spoof
# 31498 spoof
# 31499 spoof
# 31500 spoof
# 31501 spoof
# 31502 spoof
# 31503 spoof
# 31504 spoof
# 31505 spoof
# 31506 spoof
# 31507 spoof
# 31508 spoof
# 31509 spoof
# 31510 spoof
# 31511 spoof
# 31512 spoof
# 31513 spoof
# 31514 spoof
# 31515 spoof
# 31516 spoof
# 31517 spoof
# 31518 spoof
# 31519 spoof
# 31520 spoof
# 31521 spoof
# 31522 spoof
# 31523 spoof
# 31524 spoof
# 31525 spoof
# 31526 spoof
# 31527 spoof
# 31528 spoof
# 31529 spoof
# 31530 spoof
# 31531 spoof
# 31532 spoof
# 31533 spoof
# 31534 spoof
# 31535 spoof
# 31536 spoof
# 31537 spoof
# 31538 spoof
# 31539 spoof
# 31540 spoof
# 31541 spoof
# 31542 spoof
# 31543 spoof
# 31544 spoof
# 31545 spoof
# 31546 spoof
# 31547 spoof
# 31548 spoof
# 31549 spoof
# 31550 spoof
# 31551 spoof
# 31552 spoof
# 31553 spoof
# 31554 spoof
# 31555 spoof
# 31556 spoof
# 31557 spoof
# 31558 spoof
# 31559 spoof
# 31560 spoof
# 31561 spoof
# 31562 spoof
# 31563 spoof
# 31564 spoof
# 31565 spoof
# 31566 spoof
# 31567 spoof
# 31568 spoof
# 31569 spoof
# 31570 spoof
# 31571 spoof
# 31572 spoof
# 31573 spoof
# 31574 spoof
# 31575 spoof
# 31576 spoof
# 31577 spoof
# 31578 spoof
# 31579 spoof
# 31580 spoof
# 31581 spoof
# 31582 spoof
# 31583 spoof
# 31584 spoof
# 31585 spoof
# 31586 spoof
# 31587 spoof
# 31588 spoof
# 31589 spoof
# 31590 spoof
# 31591 spoof
# 31592 spoof
# 31593 spoof
# 31594 spoof
# 31595 spoof
# 31596 spoof
# 31597 spoof
# 31598 spoof
# 31599 spoof
# 31600 spoof
# 31601 spoof
# 31602 spoof
# 31603 spoof
# 31604 spoof
# 31605 spoof
# 31606 spoof
# 31607 spoof
# 31608 spoof
# 31609 spoof
# 31610 spoof
# 31611 spoof
# 31612 spoof
# 31613 spoof
# 31614 spoof
# 31615 spoof
# 31616 spoof
# 31617 spoof
# 31618 spoof
# 31619 spoof
# 31620 spoof
# 31621 spoof
# 31622 spoof
# 31623 spoof
# 31624 spoof
# 31625 spoof
# 31626 spoof
# 31627 spoof
# 31628 spoof
# 31629 spoof
# 31630 spoof
# 31631 spoof
# 31632 spoof
# 31633 spoof
# 31634 spoof
# 31635 spoof
# 31636 spoof
# 31637 spoof
# 31638 spoof
# 31639 spoof
# 31640 spoof
# 31641 spoof
# 31642 spoof
# 31643 spoof
# 31644 spoof
# 31645 spoof
# 31646 spoof
# 31647 spoof
# 31648 spoof
# 31649 spoof
# 31650 spoof
# 31651 spoof
# 31652 spoof
# 31653 spoof
# 31654 spoof
# 31655 spoof
# 31656 spoof
# 31657 spoof
# 31658 spoof
# 31659 spoof
# 31660 spoof
# 31661 spoof
# 31662 spoof
# 31663 spoof
# 31664 spoof
# 31665 spoof
# 31666 spoof
# 31667 spoof
# 31668 spoof
# 31669 spoof
# 31670 spoof
# 31671 spoof
# 31672 spoof
# 31673 spoof
# 31674 spoof
# 31675 spoof
# 31676 spoof
# 31677 spoof
# 31678 spoof
# 31679 spoof
# 31680 spoof
# 31681 spoof
# 31682 spoof
# 31683 spoof
# 31684 spoof
# 31685 spoof
# 31686 spoof
# 31687 spoof
# 31688 spoof
# 31689 spoof
# 31690 spoof
# 31691 spoof
# 31692 spoof
# 31693 spoof
# 31694 spoof
# 31695 spoof
# 31696 spoof
# 31697 spoof
# 31698 spoof
# 31699 spoof
# 31700 spoof
# 31701 spoof
# 31702 spoof
# 31703 spoof
# 31704 spoof
# 31705 spoof
# 31706 spoof
# 31707 spoof
# 31708 spoof
# 31709 spoof
# 31710 spoof
# 31711 spoof
# 31712 spoof
# 31713 spoof
# 31714 spoof
# 31715 spoof
# 31716 spoof
# 31717 spoof
# 31718 spoof
# 31719 spoof
# 31720 spoof
# 31721 spoof
# 31722 spoof
# 31723 spoof
# 31724 spoof
# 31725 spoof
# 31726 spoof
# 31727 spoof
# 31728 spoof
# 31729 spoof
# 31730 spoof
# 31731 spoof
# 31732 spoof
# 31733 spoof
# 31734 spoof
# 31735 spoof
# 31736 spoof
# 31737 spoof
# 31738 spoof
# 31739 spoof
# 31740 spoof
# 31741 spoof
# 31742 spoof
# 31743 spoof
# 31744 spoof
# 31745 spoof
# 31746 spoof
# 31747 spoof
# 31748 spoof
# 31749 spoof
# 31750 spoof
# 31751 spoof
# 31752 spoof
# 31753 spoof
# 31754 spoof
# 31755 spoof
# 31756 spoof
# 31757 spoof
# 31758 spoof
# 31759 spoof
# 31760 spoof
# 31761 spoof
# 31762 spoof
# 31763 spoof
# 31764 spoof
# 31765 spoof
# 31766 spoof
# 31767 spoof
# 31768 spoof
# 31769 spoof
# 31770 spoof
# 31771 spoof
# 31772 spoof
# 31773 spoof
# 31774 spoof
# 31775 spoof
# 31776 spoof
# 31777 spoof
# 31778 spoof
#    chroma_stft       rms  spectral_centroid  spectral_bandwidth      rolloff  \
# 0     0.487154  0.015950        1208.522263         1117.511704  2302.143895
# 1     0.360392  0.074998        1015.153562         1045.086946  2070.221126
# 2     0.372450  0.044046         993.691953         1044.403097  1973.930921
# 3     0.336277  0.093521        1167.997160         1146.765750  2255.102759
# 4     0.391243  0.042235        1023.265924         1148.364134  1995.499817
#
#    zero_crossing_rate       mfcc1       mfcc2      mfcc3      mfcc4  ...  \
# 0            0.094954 -382.710724  139.161026 -27.497173  22.212635  ...
# 1            0.074430 -286.591064  135.355698 -22.200628  59.452393  ...
# 2            0.068128 -308.211975  153.013657 -30.318661  48.148067  ...
# 3            0.073513 -234.577850  127.184479 -31.477472  55.051060  ...
# 4            0.076969 -323.652039  136.074448  -2.084312  45.361725  ...
#
#       mfcc12    mfcc13     mfcc14    mfcc15     mfcc16    mfcc17     mfcc18  \
# 0  -8.686200 -0.478648  -7.375463  1.262067 -10.458428  1.966513  -2.933967
# 1  -6.697213 -6.026350 -11.951935  1.342705  -2.657178 -5.800148  -2.491944
# 2  -9.481265  1.308795 -14.097563  1.270982  -2.771632 -0.102958  -9.643146
# 3  -5.916126  0.674749 -17.243065 -3.573194  -6.485143 -0.120859 -11.282431
# 4 -11.634926  6.641159 -15.179647 -0.050429 -10.547523 -3.394425  -0.232599
#
#      mfcc19    mfcc20      label
# 0 -8.268948 -3.409954  bona-fide
# 1  0.356558 -4.510029  bona-fide
# 2 -5.159993 -3.461776  bona-fide
# 3 -6.785034 -5.790135  bona-fide
# 4 -3.987034  2.917496  bona-fide
#
# [5 rows x 27 columns]

# %%
len(features_df)
features_df.to_excel("audio_features1.xlsx")

# %%
features_df['label'].unique()
# Out:
# array(['bona-fide', 'spoof'], dtype=object)
